# %%
# !git clone https://github.com/Kimchangheon/GCN_DSN_Drug_Discovery.git
# Out:
# Cloning into 'GCN_DSN_Drug_Discovery'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 63 (delta 25), reused 52 (delta 14), pack-reused 0
# Unpacking objects: 100% (63/63), done.

# %%
import os
os.chdir("/content/GCN_DSN_Drug_Discovery")

# %%
 DeepChem 1.3을 설치해야 에러가 뜨지 않을텐데.. 
 버전이 너무 안맞아서 일단 보류하겠음.

# %%
# !pip install deepchem
# !python train.py --gpu 0 --dataset pcba
# Out:
# ...
#      |████████████████████████████████| 552kB 4.3MB/s
# ...
# 2021-04-19 22:57:07.361784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "train.py", line 18, in <module>
#     import models.multitask_classifier as mymodel
#   File "/content/GCN_DSN_Drug_Discovery/models/multitask_classifier.py", line 30, in <module>
#     from deepchem.models.tf_new_models.graph_topology import merge_dicts
# ModuleNotFoundError: No module named 'deepchem.models.tf_new_models'

# %%
# !pip install deepchem

# %%
import deepchem

# %%
deepchem.contrib
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6ddd998a6ef4> in <module>()
# ----> 1 deepchem.contrib
#
# AttributeError: module 'deepchem' has no attribute 'contrib'

# %%
help(deepchem.contrib.one_shot_models)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-719dab3f97ac> in <module>()
# ----> 1 help(deepchem.contrib.one_shot_models)
#
# AttributeError: module 'deepchem' has no attribute 'contrib'

# %%
import keras

# %%
keras.activations

# %%
help(deepchem)

# %%
help(deepchem.utils)

# %%
help(deepchem.models)
# Out:
# Help on package deepchem.models in deepchem:
#
# NAME
#     deepchem.models - Gathers all models in one place for convenient imports
#
# PACKAGE CONTENTS
#     IRV
#     atomic_conv
#     callbacks
#     chemnet_layers
#     chemnet_models
#     cnn
#     fcnet
#     gan
#     gbdt_models (package)
#     graph_models
#     keras_model
#     layers
#     losses
#     models
#     multitask
#     normalizing_flows
#     optimizers
#     progressive_multitask
#     robust_multitask
#     scscore
#     seqtoseq
#     sklearn_models (package)
#     text_cnn
#     torch_models (package)
#
# FILE
#     /usr/local/lib/python3.7/dist-packages/deepchem/models/__init__.py

# %%
help(deepchem.molnet)
